# %% [markdown]
# <a href="https://colab.research.google.com/github/MM33NA/AI_ML_Class/blob/main/python_refresher/python_basic_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For Anaconda installation go to
# https://www.anaconda.com/download

# %% [markdown]
# #### **Google Colab Login**
#
# Steps:

# %% [markdown]
# **Two exension files for python:**
#
# .py --> Python
#
# .ipynb --> interactive python notebook
#
# - Shift + Enter --> to execute the code
#
# - Ctrl + Enter --> to exeucute the code
#
# - Use # to comment

# %% [markdown]
# Python Used for:
# - Data Science
# - Machine Learning
# - Automation
# - Webpage

# %% [markdown]
# Python can be used for simple mathematica functions and a basic calculator such as:
#
# **Mathematical Operations**
# - Addition
# - Substraction
# - Multiplication
# - Division
# - Modules
# ---

# %%
2+3
# Out:
# 5

# %%
2*5
# Out:
# 10

# %%
7/2
# Out:
# 3.5

# %%
# 7 modules 2
7%2
# Out:
# 1

# %% [markdown]
# ---
# **Data types**
#
# int
#
# float -- decimal values
#
# str -- string
#
# ---

# %%
# a is a variable
# a is nothing but a placeholder for a value

a = 2

# %%
# to check the data type --> type(data)
# python is intelligent to show a data type without we mentioning except sometimes where we might need to assign data type
type(a)
# Out:
# int

# %% [markdown]
# the data type for 2 --> Integer

# %%
b = 3.4

# %%
type(b)
# Out:
# float

# %% [markdown]
# Data type for b is float since it is in the decimal point

# %%
c = 'Abhishek'

# %%
c
# Out:
# 'Abhishek'

# %%
i = True

# %%
i
# Out:
# True

# %%
type(i)
# Out:
# bool

# %%
j = False

# %%
j
# Out:
# False

# %%
type(j)
# Out:
# bool

# %% [markdown]
# The data type for i and j is Boolean

# %% [markdown]
# ---
# - In Python everything is object
#
# - variable, tuple, everything is object
#
# ---

# %%
b
print("value of b:", b)
# Out:
# value of b: 3.4

# %% [markdown]
# ---
#
# **Print function**
# - [link text](https://) Anything that is inside the "" is a free text and can be modified as needed.
#
# - Anything after comma gives the exact value for the data
#
# ---

# %%
b
print("Value of b:", b)
print(type(b))
# Out:
# Value of b: 3.4
# <class 'float'>

# %% [markdown]
# ---
#
# **Type Casting**
# Type casting (or type conversion) in Python is the process of converting a variable from one data type to another. This is essential for ensuring data compatibility during operations, especially when working with mixed data type
#
# ---

# %%
# to convert b into integer.

x = int(b) # From float --> integer--this is called typecasting
print("Value of x:", x)
print(type(x))
# Out:
# Value of x: 3
# <class 'int'>

# %% [markdown]
# **Note** It has changed 3.4 float value to an integer class

# %%
# name --> variable
# Abhishek --> value
# to abstract the letter 's' from Abhishek:
name = "Abhishek"

# %% [markdown]
# ---
#
# - Python is 0 indexing from left to right.
# - to absract 's' from Abhishek check what indesing is 's' located in.
# - Start --> Inclusive
# - End --> Exclusive
# - Negative indexing
#   - starts from right to left but count from left to right
#   - mostly used to make it efficient use of time. For example, to abstract 'k' from Abhishek, instead of counting, it is easy to use -1 indexing which gives 'k' value
#   - negative indexing starts from -1
#
# ---

# %%
from google.colab import files
from IPython.display import Image

# Upload the image
uploaded = files.upload()

# Display the image
Image('Screenshot 2026-03-09 122015.png')
# Out:
#      <input type="file" id="files-a5c13443-7f84-43a0-917d-df1db013d96b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5c13443-7f84-43a0-917d-df1db013d96b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
name[0]
# Out:
# 'A'

# %%
# Upload the image
uploaded = files.upload()

# Display the image
Image('Screenshot 2026-04-16 174618.png')
# Out:
#      <input type="file" id="files-32e55e5f-a683-4c6e-9ea4-a5c83bcc3638" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32e55e5f-a683-4c6e-9ea4-a5c83bcc3638">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
name[4]
# Out:
# 's'

# %%
# To get Abhi --> 0:4

name[0:4]
# Out:
# 'Abhi'

# %%
# A = 0, b = 1, h = 2, i = 3, s = 4, h = 5, e = 6, k = 7
# to get h and e from Abhishek

name[5:7]
# Out:
# 'he'

# %%
#### Negative Indexing

Uploaded = files.upload()

# display the image
Image('Screenshot 2026-04-16 175824.png')
# Out:
#      <input type="file" id="files-18639de8-0850-44fe-8e1c-3519fd0ac6a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18639de8-0850-44fe-8e1c-3519fd0ac6a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
name[-4]
# Out:
# 's'

# %%
name[-8: -4]
# Out:
# 'Abhi'

# %%
name[-1]
# Out:
# 'k'

# %%
name[2:]
# Out:
# 'hishek'

# %%
# Abhishek

name[-8:]
# Out:
# 'Abhishek'

# %%
name[0:]
# Out:
# 'Abhishek'

# %%
name
# Out:
# 'Abhishek'

# %%
print(name) # better to get the output in the print statement
# Out:
# Abhishek

# %%
# Usually variable names are in lower case and shouldnot start with number
# Use underscores
# Don't use dots
# Dont Start with numbers

course_name = "Python for Data Science"

# %% [markdown]
# ### **LIST**
#
# Python lists are versatile data structures that can store multiple items in a single variable. They are ordered, changeable, and allow duplicate values.
#
# **Creating a List**
#
# Lists are created using square brackets [] or the list() constructor.

# %%
my_list = ["apple", "banana", "cherry"]
print(my_list) # Output: ['apple', 'banana', 'cherry']
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# **Accessing Elements**

# %%
print(my_list[0]) # Output: apple
print(my_list[-1]) # Output: cherry
# Out:
# apple
# cherry

# %% [markdown]
# **Modifying Lists**
#
# - Lists are mutable, meaning you can change, add, or remove items.
#
# **Adding Elements**
#
# - Use append() to add an element at the end or insert() to add at a specific position.

# %%
my_list.append("orange")
my_list.insert(1, "blueberry")
print(my_list) # Output: ['apple', 'blueberry', 'banana', 'cherry', 'orange']
# Out:
# ['apple', 'blueberry', 'banana', 'cherry', 'orange']

# %% [markdown]
# **Removing Elements**
#
# - Use remove() to remove a specific element or pop() to remove an element at a specific index.

# %%
my_list.remove("banana")
my_list.pop(2)
print(my_list) # Output: ['apple', 'blueberry', 'orange']
# Out:
# ['apple', 'blueberry', 'orange']

# %% [markdown]
# **Practice List**

# %%
l1 = [1,2,4,7,6,10,20] # Creating the list

# %%
print(l1) # Print the elements in the list
# Out:
# [1, 2, 4, 7, 6, 10, 20]

# %%
type(l1) # Check the type of l1
# Out:
# list

# %%
l1[0] # accessing the element of the list
# Out:
# 1

# %%
l1[5] # accessing the element of the list
# Out:
# 10

# %%
l2 = [] # blank list

# %%
len(l2) # length of l2
# Out:
# 0

# %%
type(l2)
# Out:
# list

# %%
# [1, 2, 4, 7, 5 10, 20]
l1[4:]
# Out:
# [6, 10, 20]

# %%
lx = [10, 20, 'Python', -5, True, 70] # List can hold different types of data

# %%
# lx: 1 = 10, 2 = 20, 3 = 'Python'
# to get the data type for the element 'Python'

type(lx[2]) # the second eleement in the lx is python, which is string. Thisis how we deal when there are different data tyles within the list
# Out:
# str

# %%
l3 = [10, 20, 40, 5, 60, 100, 4]

# %%
# adding value in the existing list

l3.append(500) # this will be appended at the last of the l3 list

# %%
l3
# Out:
# [10, 20, 40, 5, 60, 100, 4, 500]

# %%
l3.append(1000) # we can add only one element at the time. For multiple addition there's a different method

# %%
l3
# Out:
# [10, 20, 40, 5, 60, 100, 4, 500, 1000]

# %% [markdown]
# **To simplify, Append means add a at the last**
# - Use **append** to add at the last
# - Use **insert** to add at a specific position
# - Use **extend** to add multiple elements at last
#
#
# **All of the below functions are called "Methods"**
# - sort()
# - count()
# - index()
# - clear

# %%
# to add the element at a specific location, instead of append use insert

l3.insert(4, 1000)
print(l3)
# Out:
# [10, 20, 40, 5, 1000, 60, 100, 4, 500, 1000]

# %%
l3.extend([300,350,380]) # to add multiple elements at the last use extend
print(l3)
# Out:
# [10, 20, 40, 5, 1000, 60, 100, 4, 500, 1000, 300, 350, 380]

# %%
l3.insert(4, [10,10,10]) # this is still counted as the one element not multiple element --> [10,10,10]
print(l3)
# Out:
# [10, 20, 40, 5, [10, 10, 10], 1000, 60, 100, 4, 500, 1000, 300, 350, 380]

# %%
l3.pop() # it will remove a last element: 380 will be deleted from the list
# Out:
# 380

# %%
l3
# Out:
# [10, 20, 40, 5, [10, 10, 10], 1000, 60, 100, 4, 500, 1000, 300, 350]

# %%
l3.pop(4) # it will remove 4th element
# Out:
# [10, 10, 10]

# %%
l3
# Out:
# [10, 20, 40, 5, 1000, 60, 100, 4, 500, 1000, 300, 350]

# %% [markdown]
# **Note**
# - **pop:** remove element at a specific index
# - **remove:** remove element by value
# - **clear:** remove all the items from the list
# - **del:** removes everything including variable name and values it holds

# %%
l1 = [1,2,3,4,5,1,10]
l1
# Out:
# [1, 2, 3, 4, 5, 1, 10]

# %%
l1.remove(1)

# %%
l1
# Out:
# [2, 3, 4, 5, 1, 10]

# %%
l1.clear() #Remove all the items from the list

# %%
l1
# Out:
# []

# %%
l1 = [2,5,6,10] # remove the element 5

# %%
l1.remove(5)

# %%
l1
# Out:
# [2, 6, 10]

# %%
ds_languages = ['Python', 'Matlab', 'R', 'Java']

# %%
ds_languages.pop() # it removes the last index
# Out:
# 'Java'

# %%
ds_languages
# Out:
# ['Python', 'Matlab', 'R']

# %%
ds_languages.remove('Matlab') # it removes the element name 'Matlab

# %%
ds_languages
# Out:
# ['Python', 'R']

# %%
ds_languages.pop(1) # to remove 'R' which is index 1
# Out:
# 'R'

# %%
ds_languages
# Out:
# ['Python']

# %%
del(ds_languages) # to delete everything including variable ds_languages and any value it holds

# %%
ds_languages # since we used a del function the variable ds_languages is deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4104/1062108728.py in <cell line: 0>()
# ----> 1 ds_languages # since we used a del function the variable ds_languages is deleted
#
# NameError: name 'ds_languages' is not defined

# %% [markdown]
# **Note:**
# [ ] we use for the list and *indexing*

# %%
l1 = [2,3,4,52,4,5,2,7]

# %%
l1.index(4) # what is the index of 4?
# Out:
# 2

# %% [markdown]
# In this case, when we say index(4) we are counting from 0 index until 4, for which the element is 4, but where does the four occurs first? 0 = 2, 3= 1, 4 =2. Since the first occurence of 4 is in the index 2, it prints 2 as a response. It shows the first occurence of the element

# %%
l1.index(52) # 52 is the 3rd index in the list
# Out:
# 3

# %%
l1.index(2) # 2 is in the 0 index in the list
# Out:
# 0

# %%
l1.count(2) # it shows how many times 2 is counted in the list --> frequency of the element
# Out:
# 2

# %%
l1.sort() # it will sort the list 'l1' since all the elements are numeric. However, list can contain all kinds of element. In those cases sort function will not work

# %%
l1.sort(reverse=True) # for descending order
l1
# Out:
# [52, 7, 5, 4, 4, 3, 2, 2]

# %%
l1
# Out:
# [52, 7, 5, 4, 4, 3, 2, 2]

# %%
l1 = [10, 20, 30]
l2 = [100, 200, 300]

# %%
l1 + l2 # it is not a mathematical operation. it will just concatenate two list
# Out:
# [10, 20, 30, 100, 200, 300]

# %%
l1.clear() #remove all items from the list l1

# %%
# list of list or nested list

list_of_list = [[1,2,3], [10,20,30], [100,200,300,400]]

# %%
len(list_of_list)
# Out:
# 3

# %%
list_of_list[1]
# Out:
# [10, 20, 30]

# %%
#extract 20 from list 1
list_of_list[1][2]
# Out:
# 30

# %%
l1 = [2,3,4,5] # change the element 4
l1
# Out:
# [2, 3, 4, 5]

# %%
l1[2] = 40 # first reach the element that you want to change here 4 = index 2

# %%
l1 # changed the element 4 --> 40
# Out:
# [2, 3, 40, 5]

# %% [markdown]
# ### **Tuple**
#
# - immutable --> can't alter
# - small brackets automatically means ()
# - ordered: whatever order it is saved it will be in the same order

# %%
t1 = (1,2,3,4) # tuple uses ()
t1
# Out:
# (1, 2, 3, 4)

# %%
type(t1) # tyle of t1 --> tuple
# Out:
# tuple

# %%
t1[2] # the value of index 2 = 3; indexing works in tuple
# Out:
# 3

# %%
t2 = (10,20)

# %%
t3 = t1 + t2 # concatenate will work as we are not changing any elements

# %%
t3
# Out:
# (1, 2, 3, 4, 10, 20)

# %%
len(t3) # length works in tuple
# Out:
# 6

# %%
t3.pop() # pop function doesnt work in tuple as it is immutable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4104/3246603003.py in <cell line: 0>()
# ----> 1 t3.pop() # pop function doesnt work in tuple as it is immutable
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t2 = list(t2) #this is typecasting-- here we are saying change t2 --> list type

# %%
type(t2)
# Out:
# list

# %%
t = 1, 2, 3  # another way to define tupple, but least common

# %%
type(t)
# Out:
# tuple

# %%
t4 = (1) #in case of only one element, it wount give tuple type if we do not insert comma after single value

# %%
type(t4)
# Out:
# int

# %%
t4 = (1,) # in case of only one element use comma to list it as a tuple

# %%
type(t4) # it gives tuple
# Out:
# tuple

# %% [markdown]
# ## **Sets**
#
# - Set: defined using a curly bracket {}
# - unordered
# - can only hold unique elements

# %%
s1 = {1,2,3,4} # use {} to define set
s1 # it can give ordered result but we can't guarantee it always give ordered result
# Out:
# {1, 2, 3, 4}

# %%
type(s1) # type of s1 is set
# Out:
# set

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1[2] # this function doesn't work because it doesn't know which element is in which index as it is unordered
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4104/1658686592.py in <cell line: 0>()
# ----> 1 s1[2] # this function doesn't work because it doesn't know which element is in which index as it is unordered
#
# TypeError: 'set' object is not subscriptable

# %%
s = set()

# %%
len(s)
# Out:
# 0

# %%
type(s1)
# Out:
# set

# %%
s1.update([100,200,300]) # update the set adding the list

# %%
s1
# Out:
# {1, 2, 3, 4, 100, 200, 300}

# %%
s1.pop() # indexing creates problem due to the unordered characterstics of set.
# Out:
# 1

# %%
s1.remove(100) # deleting the element 100

# %%
s1
# Out:
# {2, 3, 4, 200, 300}

# %%
s1 = {1,2,3}
s2 = {3,4,5}

# %%
s1.union(s2) # it gives 1, 2, 3, 4, 5
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.intersection(s2) # the common between two sets is 3 so it gives the intersecting value 3
# Out:
# {3}

# %%
s1.difference(s2) #to see the different value in s1 compared to s2 --> 1, 2
# Out:
# {1, 2}

# %%
s1 = {1,2,3,4,5,22,3,54,3,4,5,5,} # set holds only the unique value

# %%
s1 # it deletes all the duplicate value since sets can hold only unique values
# Out:
# {1, 2, 3, 4, 5, 22, 54}

# %%
'''
list[]
tuple()
sets{}
'''
# Out:
# '\nlist[]\ntuple()\nsets{}\n'

# %% [markdown]
# ### **Dicionary**
#
# - dict
# - dictionary is also defined by using {}
# - key + value => keyvalue pair
# - no duplicate keys allowed

# %%
# keys --> name, age, city; to define Key use "":
# value --> Rahul, 25, and Delhi; strings are inside ""
emp  = {"name": "Rahul",
        "age": 25,
        "City": "Delhi"}

# %%
emp.keys() # it gives the dictionay keys
# Out:
# dict_keys(['name', 'age', 'City'])

# %%
emp.values () # it gives the dictionary values
# Out:
# dict_values(['Rahul', 25, 'Delhi'])

# %%
emp.get("name") # it gives the value of the key name
# Out:
# 'Rahul'

# %% [markdown]
#  **Example of nested dictionary**

# %%
emp = {"name": ["Amit", "leo", "Ajay"], # Keys can hold multiple values
       "age": [30, 23, 43],
       "city": "Delhi"} # not mandatory to have equal number of vales as name and age

# %%
# not necessary that key should be string only, it could be numeric as well
student = {101: {
    'name': 'John',
    'age': 26,
},
           102:{
               'name': 'Alice',
               'age': 25
           }}

# %%
student
# Out:
# {101: {'name': 'John', 'age': 26}, 102: {'name': 'Alice', 'age': 25}}

# %%
emp
# Out:
# {'name': ['Amit', 'leo', 'Ajay'], 'age': [30, 23, 43], 'city': 'Delhi'}
